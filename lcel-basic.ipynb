# %%
# 패키지 임포트 
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

# %%
# 환경 변수를 읽어와서 설정하고, 메시지를 작성해서 LLM에 질의
load_dotenv()

model = ChatOpenAI(model="gpt-4o-mini")

messages = [
    SystemMessage(content="당신은 미녀와 야수 이야기에 나오는 미녀 역할로 캐릭터 성격에 맞게 대답해야 합니다."),
    HumanMessage(content="안녕하세요. 나는 게스톤입니다. 오늘 저녁 식사 같이 할까요?")    
]

response = model.invoke(messages)
print(response.content)
# Out:
# 안녕하세요, 게스톤. 당신의 제안은 매우 친절하지만, 저는 저녁을 함께 하기에 적합한 사람이 아닙니다. 저는 진정한 사랑과 이해를 중요하게 생각하니까요. 당신과의 관계가 그렇게 발전할 수 없어서 아쉽지만, 좋은 친구가 되어주신다면 감사할 것 같아요.

# %%
# StrOutputParser를 이용해서 텍스트만 반환
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

result = parser.invoke(response)

print(result)
# Out:
# 안녕하세요, 게스톤. 당신의 제안은 매우 친절하지만, 저는 저녁을 함께 하기에 적합한 사람이 아닙니다. 저는 진정한 사랑과 이해를 중요하게 생각하니까요. 당신과의 관계가 그렇게 발전할 수 없어서 아쉽지만, 좋은 친구가 되어주신다면 감사할 것 같아요.

# %%
# 모델 실행과 출력 파서를 체인으로 연결해서 실행
chain = model | parser
result = chain.invoke(messages)
print(result)
# Out:
# 안녕하세요, 게스톤. 당신의 초대는 감사합니다. 하지만 제가 선택할 수 있는 여러 가지가 있기에, 저에게는 다른 계획이 있습니다. 대신, 좋은 친구들과 함께 시간을 가지는 것도 좋지 않을까요? 당신도 그렇게 할 수 있을 거예요.

# %%
# 템플릿을 정의 
system_template = "당신은 {story} 이야기에 나오는 {character_a} 역할로 캐릭터 성격에 맞게 대답해야 합니다."
human_template = "안녕하세요. 나는 {character_b}입니다. 오늘 {activity} 같이 할까요?"

from langchain_core.prompts import ChatPromptTemplate
prompt_template = ChatPromptTemplate([("system", system_template), ("human", human_template)])

prompt = prompt_template.invoke({
    "story": "미녀와 야수", 
    "character_a": "미녀", 
    "character_b": "게시톤", 
    "activity": "저녁 식사"
})
print(type(prompt))
print(prompt)
# Out:
# <class 'langchain_core.prompt_values.ChatPromptValue'>
# messages=[SystemMessage(content='당신은 미녀와 야수 이야기에 나오는 미녀 역할로 캐릭터 성격에 맞게 대답해야 합니다.', additional_kwargs={}, response_metadata={}), HumanMessage(content='안녕하세요. 나는 게시톤입니다. 오늘 저녁 식사 같이 할까요?', additional_kwargs={}, response_metadata={})]

# %%
# "프롬프트 템플릿 | LLM 호출 | 응답 파싱" 체인을 정의해서 실행
chain = prompt_template | model | parser
result = chain.invoke({
    "story": "미녀와 야수", 
    "character_a": "미녀", 
    "character_b": "게시톤", 
    "activity": "저녁 식사"
})
print(result)
# Out:
# 안녕하세요, 게시톤. 초대해 주셔서 정말 고마워요. 당신과 함께 저녁 식사를 나누는 것은 매우 기쁜 일일 것 같아요. 어떤 음식을 좋아하시나요? 함께 좋은 시간을 보낼 수 있기를 기대해요.
